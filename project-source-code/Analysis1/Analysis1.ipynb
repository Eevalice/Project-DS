# %% [markdown]
# # Analysis 1 of the Used Car Vehicles in Germany Available on eBay

# %% [markdown]
# ## General Data Analysis of the Team

# %%
# %matplotlib inline

# %%
# importing required libraries
import os
import subprocess
import stat
import numpy as np
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt
import warnings
from datetime import datetime
sns.set(style="white")

# %%
# absolute path till parent folder
abs_path = os.getcwd()
path_array = abs_path.split("/")
path_array = path_array[:len(path_array)-1]
homefolder_path = ""
for i in path_array[1:]:
    homefolder_path = homefolder_path + "/" + i

# %%
# path to clean data
clean_data_path = homefolder_path + "C:/Users/vincent/Documents/GitHub/Recent-Car-Changes-Dataset/CleanData/CleanedDataSet/cleaned_autos.csv"

# reading csv into raw dataframe
df = pd.read_csv(clean_data_path,encoding="latin-1")

# %% [markdown]
# ## Distribution of Vehicles based on Year of Registration

# %%
# Distribution of vehicles based on year of registration
fig, ax = plt.subplots(figsize=(8,6))
sns.histplot(df["yearOfRegistration"], color="#33cc33",kde=True, ax=ax)
ax.set_title('Distribution of vehicles based on Year of Registration', fontsize= 15)
plt.ylabel("Density (KDE)", fontsize= 15)
plt.xlabel("Year Of Registration", fontsize= 15)
plt.show()

# %%
# saving the plot
fig.savefig(abs_path + "/Plots/vehicle-distribution.png")

# %% [markdown]
# ## Variation of the price range by the vehicle type

# %%
# Set style
sns.set_style("whitegrid")

# Create a figure and axes
fig, ax = plt.subplots(figsize=(8,6))

# Create boxplot with smaller box width
sns.boxplot(x="vehicleType", y="price", data=df, width=0.5)

# Add text, labels, and show plot
ax.text(5.25, 27000, "Boxplot for price range by vehicle type", fontsize=18, color="r", ha="center", va="center")
ax.xaxis.set_label_text("Type Of Vehicle", fontdict= {'size':14})
ax.yaxis.set_label_text("Price Range", fontdict= {'size':14})

# Rotate x-axis labels to prevent overlap
plt.xticks(rotation=45)

plt.show()

# %%
# saving the plot
fig.savefig(abs_path + "/Plots/price-vehicleType-boxplot.png")

# %% [markdown]
# ## Total count of vehicles by type available on ebay for sale

# %%
warnings.filterwarnings('ignore', category=UserWarning)

# Count plot to show the number of vehicles belonging to each vehicleType
sns.set_style("white")

# Create count plot
g = sns.catplot(x="vehicleType", data=df, kind="count", palette="BuPu", height=6, aspect=1.5)

# Set labels and title
g.ax.xaxis.set_label_text("Type of Vehicle", fontdict= {'size':16})
g.ax.yaxis.set_label_text("Total No of vehicles for sale", fontdict= {'size':16})
g.ax.set_title("Total count of vehicles on sale as per vehicle type", fontdict= {'size':18})

# Display counts on top of bars
for p in g.ax.patches:
    g.ax.annotate(format(p.get_height(), '.0f'), 
                  (p.get_x() + p.get_width() / 2., p.get_height()), 
                  ha = 'center', 
                  va = 'center', 
                  xytext = (0, 10), 
                  textcoords = 'offset points')

# Show the plot
plt.show()
g.savefig(abs_path + "/Plots/price-vehicleType-boxplot.png")

# %%
# saving the plot
g.savefig(abs_path + "/Plots/count-vehicleType.png")
